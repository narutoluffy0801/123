# %%
import pandas as pd
df=pd.read_excel('house_price_dống-da.xlsx')
print(df.shape)
print(df.dtypes)
df.head()
# Out:
# (1000, 18)
# title                        object
# address                      object
# area                        float64
# price                       float64
# postDate             datetime64[ns]
# land_certificate             object
# house_direction              object
# balcony_direction            object
# toilet                      float64
# bedroom                     float64
# floor                       float64
# type_of_land                 object
# street_name                  object
# ward_name                    object
# district_name                object
# city_name                    object
# lat                         float64
# long                        float64
# dtype: object
# C:\Users\quochau_bui\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                title  \
# 0  Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# ...

# %%
df[(df['land_certificate'] == 'Sổ đỏ') & ((df['ward_name'] =='Phường Trung Liệt')|(df['ward_name'] =='Phường Khâm Thiên'))]
df.head()
# Out:
#                                                title  \
# 0  Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 1  Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2  Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 3  Bán nhà 6 tầng mới kinh doanh mặt ngõ 1194 Đườ...
# 4  Bán nhà mặt phố Thái Hà 70m2, 5 tầng, 4.5m mặt...
#
#                                              address  area    price  \
# 0  Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...  50.0  14700.0
# 1  Đường Tây Sơn, Phường Trung Liệt, Đống Đa, Hà...  35.0  12500.0
# 2  Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...  57.0   4200.0
# 3  Ngõ 1194, Đường Láng, Phường Láng Thượng, Đố...  62.0  11000.0
# 4   Phố Thái Hà, Phường Trung Liệt, Đống Đa, Hà Nội  70.0  36000.0
#
#     postDate land_certificate house_direction balcony_direction  toilet  \
# 0 2021-01-01            Sổ đỏ             NaN               NaN     4.0
# 1 2021-02-19            Sổ đỏ             NaN               NaN     NaN
# ...

# %%
df1 = df[['address', 'price','house_direction','balcony_direction','land_certificate','bedroom','floor']]
df1[(df1['land_certificate'] == 'Sổ đỏ') & (df['bedroom'] >= 3.0)]
df1
# Out:
#                                                address    price  \
# 0    Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...  14700.0
# 1    Đường Tây Sơn, Phường Trung Liệt, Đống Đa, Hà...  12500.0
# 2    Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...   4200.0
# 3    Ngõ 1194, Đường Láng, Phường Láng Thượng, Đố...  11000.0
# 4     Phố Thái Hà, Phường Trung Liệt, Đống Đa, Hà Nội  36000.0
# ..                                                 ...      ...
# 995  Đường Yên Lãng, Phường Láng Hạ, Đống Đa, Hà...  17500.0
# 996  Đường Yên Lãng, Phường Trung Liệt, Đống Đa, ...  17500.0
# 997    Phố Xã Đàn, Phường Ô Chợ Dừa, Đống Đa, Hà Nội  24800.0
# 998  Hồ Văn Chương, Phường Văn Chương, Quận Đống Đa...   8100.0
# 999  Phố Chùa Bộc, Phường Khương Thượng, Đống Đa, ...  45000.0
#
#     house_direction balcony_direction land_certificate  bedroom  floor
# 0               NaN               NaN            Sổ đỏ      6.0    6.0
# ...

# %%
import pandas as pd
df=pd.read_excel('house_price_dống-da.xlsx')
types=df.type_of_land.unique()
print(types)
df.groupby('type_of_land')['price'].median()
df.groupby('type_of_land')['price'].min()
df.groupby('type_of_land')['price'].max()
# Out:
# ['Bán nhà riêng\n ' 'Bán nhà mặt phố\n ' 'Tập thể, cư xá' 'Bán nhà riêng'
#  'Bán nhà mặt phố' 'Chung cư' 'Bất động sản khác' 'Bất động sản khác\n '
#  'Đất thổ cư']
# type_of_land
# Bán nhà mặt phố            4.5
# Bán nhà mặt phố\n       5950.0
# Bán nhà riêng            780.0
# Bán nhà riêng\n         1400.0
# Bất động sản khác         30.0
# Bất động sản khác\n     9870.0
# Chung cư                 530.0
# Tập thể, cư xá           450.0
# Đất thổ cư              3680.0
# Name: price, dtype: float64

# %%
import pandas as pd
df=pd.read_excel('house_price_dống-da.xlsx')
df1 = df[['ward_name', 'floor','bedroom','toilet','land_certificate','price']]
print(df1.head())
types=df.ward_name.unique()
print(types)
df1.groupby('ward_name')['floor'].median()
df1.groupby('ward_name')['bedroom'].median()
df1.groupby('ward_name')['toilet'].median()
# Out:
#             ward_name  floor  bedroom  toilet land_certificate    price
# 0   Phường Trung Liệt    6.0      6.0     4.0            Sổ đỏ  14700.0
# 1   Phường Trung Liệt    6.0      NaN     NaN            Sổ đỏ  12500.0
# 2   Phường Khâm Thiên    4.0      8.0     3.0            Sổ đỏ   4200.0
# 3  Phường Láng Thượng    6.0      5.0     6.0            Sổ đỏ  11000.0
# 4   Phường Trung Liệt    5.0      6.0     NaN            Sổ đỏ  36000.0
# ['Phường Trung Liệt' 'Phường Khâm Thiên' 'Phường Láng Thượng'
#  'Phường Quang Trung' 'Phường Láng Hạ' 'Phường Trung Phụng'
#  'Phường Kim Liên' 'Phường Nam Đồng' 'Phường Ô Chợ Dừa' 'Phường Hàng Bột'
#  'Phường Thịnh Quang' 'Phường Phương Mai' 'Phường Cát Linh'
#  'Phường Khương Thượng' 'Phường Quốc Tử Giám' 'Phường Trung Tự'
#  'Phường Văn Chương' nan 'Phường Phương Liên' 'Phường Thổ Quan'
#  'Phường Ngã Tư Sở' 'Phường Văn Miếu']
# ward_name
# Phường Cát Linh         3.5
# Phường Hàng Bột         4.0
# Phường Khâm Thiên       3.0
# ...
